# %% [markdown]
# # Build P9 (ATPase) protein tree

# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import pandas as pd
import os

# %%
def extract_faa(gb_file, name):
    i = 1
    
    faa_records = []
    
    for record in SeqIO.parse(gb_file, 'genbank'):
        for feature in record.features:
            if feature.type == 'CDS':
                aa_seq = feature.qualifiers['translation'][0]
                aa_record = SeqRecord(Seq(aa_seq), id=f'{name}_orf{i}', name='', description='')
                faa_records.append(aa_record)
                i += 1
    
    return faa_records

def read_tblout(tblout):
    df = pd.read_csv(tblout,
                 delim_whitespace=True,
                 comment='#',
                 header=None)
    
    # parse and label column
    df = df[df.columns[:5]]
    df.columns = ['target', '-', 'query', '-',  'full_eval']
    
    
    df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]
    df = df[['acc', 'target', 'query', 'full_eval']]
    
    df = df[df['full_eval'] < 0.01]
    
    # select best hit for annotation
    df = df.sort_values(by=['acc', 'target', 'full_eval'], ascending=[True, True, False])
    df = df.drop_duplicates(subset=['target'], keep='first')
    
    return df

# %% [markdown]
# ## Get P9 sequences

# %%
# list with aa sequences for P9 proteins
p9_list = []

# result will be saved here
p9_all_faa = '../data/tree/P9/P9.faa'

# %% [markdown]
# ### This study's

# %%
# get selection of alphatectiviruses
sspp = ['PRDobsidian', 'PRDpistachio', 'PRDaquamarine',
        'PRDcanary', 'PRDsepia', 'PRDwine',
        'PRDavocado', 'PRDamber', 'PRDforest',
        'PRDcobalt', 'PRDindigo']


# append aminoacid sequences corresponding to those genomes
for record in SeqIO.parse('../data/models/faa/IX.faa', 'fasta'):
    isolate_name = record.id.split('_IX')[0]
    if isolate_name in sspp:
        record.id = isolate_name
        record.name = ''
        record.description = ''
        p9_list.append(record)

# %% [markdown]
# #### NCBI

# %%
# run hmmer with ATPase model on ncbi tectiviruses

#!hmmsearch \
#    --tblout '../data/tecti_genomes/NCBI/hmmer/p9.tbl' \
#    '../data/models/hmm/IX.2.hmm' \
#    '../data/tecti_genomes/NCBI/hmmer/all_ncbi_orfs.faa' \
#    > /dev/null

# %%
# add p9 hits to list
df_ncbi_hits = read_tblout('../data/tecti_genomes/NCBI/hmmer/p9.tbl')

for record in SeqIO.parse('../data/tecti_genomes/NCBI/hmmer/all_ncbi_orfs.faa', 'fasta'):
    if record.id in df_ncbi_hits[df_ncbi_hits['query'] == 'IX.2']['target'].to_list():
        record.name = ''
        record.description = ''
        p9_list.append(record)
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]

# %%
# add PRD1 and PR4
for record in SeqIO.parse('../data/tecti_genomes/NCBI/gb/ref_p9.faa', 'fasta'):
    p9_list.append(record)

# %% [markdown]
# #### JGI

# %%
# run hmmer with ATPase model on jgi imgvr tectiviruses

#!hmmsearch \
#    --tblout '../data/tecti_genomes/JGI_IMGVR/hmmer/p9.tbl' \
#    '../data/models/hmm/IX.2.hmm' \
#    '../data/tecti_genomes/JGI_IMGVR/hmmer/all_jgi_orfs.faa' \
#    > /dev/null

# %%
# add p9 hits to list
df_jgi_hits = read_tblout('../data/tecti_genomes/JGI_IMGVR/hmmer/p9.tbl')

for record in SeqIO.parse('../data/tecti_genomes/JGI_IMGVR/hmmer/all_jgi_orfs.faa', 'fasta'):
    if record.id in df_jgi_hits[df_jgi_hits['query'] == 'IX.2']['target'].to_list():
        record.name = ''
        record.description = ''
        p9_list.append(record)
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]

# %% [markdown]
# #### Yutin (2018)

# %%
# run hmmer with ATPase model on Yutin, et al. tectiviruses

#!hmmsearch \
#    --tblout '../data/tecti_genomes/Yutin/hmmer/p9.tbl' \
#    '../data/models/hmm/IX.2.hmm' \
#    '../data/tecti_genomes/Yutin/hmmer/all_yutin_orfs.faa' \
#    > /dev/null

# %%
# add p9 hits to list
df_yutin_hits = read_tblout('../data/tecti_genomes/Yutin/hmmer/p9.tbl')

for record in SeqIO.parse('../data/tecti_genomes/Yutin/hmmer/all_yutin_orfs.faa', 'fasta'):
    if record.id in df_yutin_hits[df_yutin_hits['query'] == 'IX.2']['target'].to_list():
        record.name = ''
        record.description = ''
        p9_list.append(record)
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]

# %%
# Save result
#SeqIO.write(p9_list, p9_all_faa, 'fasta')

# %% [markdown]
# ## Explore results

# %% [markdown]
# ### NCBI

# %%
# read hits table
df_ncbi_hits = read_tblout('../data/tecti_genomes/NCBI/hmmer/p9.tbl')

# read metadata table
df_ncbi_metadata = pd.read_csv('../data/tecti_genomes/NCBI/tectivirus_metadata.tsv', sep='\t')
df_ncbi_metadata = df_ncbi_metadata[df_ncbi_metadata['genus'] != '-']
df_ncbi_metadata = df_ncbi_metadata[df_ncbi_metadata['genus'] != 'Alphatectivirus']

pivot_ncbi_hits = df_ncbi_hits.pivot(index='acc', columns='query', values='full_eval').reset_index().fillna('-')
df_ncbi_metadata.merge(pivot_ncbi_hits, on='acc', how='left')
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]
#            acc              genus                species_name  \
# 0  NC_011523.1     Betatectivirus         Betatectivirus AP50
# 1  NC_005258.1     Betatectivirus        Betatectivirus Bam35
# 2  NC_006945.1     Betatectivirus        Betatectivirus GIL16
# 3   MZ089978.1     Betatectivirus         Betatectivirus sato
# 4   MZ089979.1     Betatectivirus         Betatectivirus sole
# 5  NC_022094.1     Betatectivirus         Betatectivirus Wip1
# 6  NC_055059.1    Deltatectivirus  Deltatectivirus forthebois
# 7  NC_055060.1    Deltatectivirus    Deltatectivirus wheeheim
# 8  NC_055061.1  Epsilontectivirus      Epsilontectivirus toil
# 9  NC_042083.1    Gammatectivirus         Gammatectivirus GC1
#
#                          isolate    len           host_class  \
# 0            Bacillus phage AP50  14398              Bacilli
# 1          Bacillus phage Bam35c  14935              Bacilli
# 2          Bacillus phage GIL16c  14844              Bacilli
# 3            Bacillus phage Sato  14852              Bacilli
# 4            Bacillus phage Sole  14444              Bacilli
# 5            Bacillus phage Wip1  14319              Bacilli
# 6  Streptomyces phage Forthebois  18251        Actinomycetia
# 7    Streptomyces phage WheeHeim  18266        Actinomycetia
# 8         Rhodococcus phage Toil  17253        Actinomycetia
# 9        Gluconobacter phage GC1  16523  Alphaproteobacteria
#
#                   host_sp          IX.2
# 0      Bacillus anthracis  2.500000e-55
# 1  Bacillus thuringiensis  3.100000e-58
# 2  Bacillus thuringiensis  9.600000e-57
# 3         Bacillus cereus  1.500000e-56
# 4   Bacillus cereus VD166  6.900000e-57
# 5      Bacillus anthracis  3.900000e-55
# 6    Streptomyces scabiei  2.800000e-36
# 7    Streptomyces scabiei  9.300000e-36
# 8      Rhodococcus opacus  1.900000e-65
# 9   Gluconobacter cerinus  6.200000e-74

# %% [markdown]
# ### JGI

# %%
df_jgi_hits = read_tblout('../data/tecti_genomes/JGI_IMGVR/hmmer/p9.tbl')

df_jgi_metadata = pd.read_csv('../data/tecti_genomes/JGI_IMGVR/JGI_metadata.tsv', sep='\t')

pivot_jgi_hits = df_jgi_hits.pivot(index='acc', columns='query', values='full_eval').reset_index().fillna('-')
df_jgi_metadata.merge(pivot_jgi_hits, on='acc', how='left')
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]
#                    acc  img_taxon_id  \
# 0     Ga0500005_002616    3300050116
# 1     Ga0500006_002682    3300050117
# 2     Ga0500006_012856    3300050117
# 3     Ga0500009_001431    3300050120
# 4     Ga0500011_004634    3300050122
# 5     Ga0500012_004241    3300050123
# 6     Ga0500013_005094    3300050124
# 7    Ga0500017_0003996    3300050128
# 8     Ga0500018_001608    3300050129
# 9     Ga0500022_002121    3300050132
# 10    Ga0500022_006983    3300050132
# 11   Ga0500032_0002123    3300050138
# 12    Ga0501157_006299    3300050150
# 13    Ga0500030_003738    3300050192
# 14  Ga0505706_00067931    3300050821
# 15  Ga0505706_00072834    3300050821
# 16  Ga0505706_00075008    3300050821
# 17  Ga0505706_00075641    3300050821
# 18  Ga0505706_00078677    3300050821
# 19  Ga0505706_00084197    3300050821
# 20  Ga0505706_00084834    3300050821
# 21  Ga0505706_00087319    3300050821
# 22  Ga0505706_00093977    3300050821
# 23  Ga0505706_00098891    3300050821
# 24  Ga0505706_00117367    3300050821
# 25  Ga0505706_00127399    3300050821
# 26  Ga0505706_00137823    3300050821
# 27  Ga0505706_00138351    3300050821
# 28  Ga0505706_00153685    3300050821
# 29  Ga0505706_00231171    3300050821
# 30  Ga0505706_00332338    3300050821
# 31  Ga0505706_00334178    3300050821
# 32  Ga0505706_00344671    3300050821
# 33  Ga0505706_00373652    3300050821
# 34  Ga0505706_00425488    3300050821
# 35  Ga0505706_00937364    3300050821
# 36  Ga0505706_00969868    3300050821
# 37  Ga0505706_01001969    3300050821
#
#                                           sample_name    len         loc  \
# 0   Peatland microbial communities from Stordalen ...  19730      sweden
# 1   Peatland microbial communities from Stordalen ...  20094      sweden
# 2   Peatland microbial communities from Stordalen ...   5558      sweden
# 3   Peatland microbial communities from Stordalen ...  17036      sweden
# 4   Peatland microbial communities from Stordalen ...   4396      sweden
# 5   Peatland microbial communities from Stordalen ...   4422      sweden
# 6   Peatland microbial communities from Stordalen ...   4816      sweden
# 7   Peatland microbial communities from Stordalen ...  11142      sweden
# 8   Peatland microbial communities from Stordalen ...  18742      sweden
# 9   Peatland microbial communities from Stordalen ...  18125      sweden
# 10  Peatland microbial communities from Stordalen ...   7686      sweden
# 11  Peatland microbial communities from Stordalen ...  19102      sweden
# 12  Alder tree leaf litter microbial communities f...   6962  washington
# 13  Peatland microbial communities from Stordalen ...  16031      sweden
# 14  Co-assembly of Harvard Forest metagenomes from...  17295     harvard
# 15  Co-assembly of Harvard Forest metagenomes from...  16739     harvard
# 16  Co-assembly of Harvard Forest metagenomes from...  16516     harvard
# 17  Co-assembly of Harvard Forest metagenomes from...  16449     harvard
# 18  Co-assembly of Harvard Forest metagenomes from...  16158     harvard
# 19  Co-assembly of Harvard Forest metagenomes from...  15661     harvard
# 20  Co-assembly of Harvard Forest metagenomes from...  15610     harvard
# 21  Co-assembly of Harvard Forest metagenomes from...  15398     harvard
# 22  Co-assembly of Harvard Forest metagenomes from...  14878     harvard
# 23  Co-assembly of Harvard Forest metagenomes from...  14526     harvard
# 24  Co-assembly of Harvard Forest metagenomes from...  13401     harvard
# 25  Co-assembly of Harvard Forest metagenomes from...  12896     harvard
# 26  Co-assembly of Harvard Forest metagenomes from...  12426     harvard
# 27  Co-assembly of Harvard Forest metagenomes from...  12402     harvard
# 28  Co-assembly of Harvard Forest metagenomes from...  11796     harvard
# 29  Co-assembly of Harvard Forest metagenomes from...   9693     harvard
# 30  Co-assembly of Harvard Forest metagenomes from...   8116     harvard
# 31  Co-assembly of Harvard Forest metagenomes from...   8094     harvard
# 32  Co-assembly of Harvard Forest metagenomes from...   7972     harvard
# 33  Co-assembly of Harvard Forest metagenomes from...   7662     harvard
# 34  Co-assembly of Harvard Forest metagenomes from...   7184     harvard
# 35  Co-assembly of Harvard Forest metagenomes from...   4822     harvard
# 36  Co-assembly of Harvard Forest metagenomes from...   4737     harvard
# 37  Co-assembly of Harvard Forest metagenomes from...   4659     harvard
#
#             IX.2
# 0   4.000000e-48
# 1   4.000000e-48
# 2   1.700000e-45
# 3   7.200000e-59
# 4   3.400000e-62
# 5   3.300000e-62
# 6   3.300000e-62
# 7   4.000000e-48
# 8   4.000000e-48
# 9   9.800000e-41
# 10  9.400000e-43
# 11  2.600000e-64
# 12  4.500000e-52
# 13  4.000000e-48
# 14  1.100000e-57
# 15  1.400000e-44
# 16  3.200000e-40
# 17  6.400000e-29
# 18  2.900000e-60
# 19  4.500000e-49
# 20  3.700000e-44
# 21  1.500000e-55
# 22  2.900000e-52
# 23  9.200000e-46
# 24  7.000000e-58
# 25  5.600000e-51
# 26  1.300000e-41
# 27  4.500000e-59
# 28  9.500000e-42
# 29  1.700000e-49
# 30           NaN
# 31  1.200000e-60
# 32  6.000000e-42
# 33  8.900000e-56
# 34  1.600000e-28
# 35  3.200000e-59
# 36  2.900000e-50
# 37           NaN

# %% [markdown]
# ## Yutin

# %%
df_yutin_hits = read_tblout('../data/tecti_genomes/Yutin/hmmer/p9.tbl')

# explore results
df_yutin_metadata = pd.read_csv('../data/tecti_genomes/Yutin/yutin_metadata.tsv', sep='\t')

pivot_yutin_hits = df_yutin_hits.pivot(index='acc', columns='query', values='full_eval').reset_index().fillna('-')
df_yutin_metadata.merge(pivot_yutin_hits, on='acc', how='left')
# Out:
# /tmp/ipykernel_31346/3433487581.py:27: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df['acc'] = df['target'].str.rsplit('_', 1, expand=True)[0]
#               acc                   environment    len          IX.2
# 0  LNFM01013825.1   Activated carbon metagenome  10153  4.000000e-60
# 1  FRDC01003407.1         freshwater metagenome  17409  3.200000e-25
# 2  LNFM01009513.1   Activated carbon metagenome  14103  1.900000e-32
# 3  JRYJ01001167.1  Activated sludge metagenome   17872  5.600000e-29

# %% [markdown]
# ## Build tree

# %%
# align resulting sequences to model
#!hmmalign --trim '../data/models/hmm/IX.2.hmm' '../data/tree/P9/P9.faa' | esl-reformat --gapsym='-' afa - > '../data/tree/P9/P9.afa'

# %%
# give them nice readable names for phylip format
name_dict = dict(zip(df_ncbi_metadata['acc'], df_ncbi_metadata['species_name'].str.replace('tectivirus', '').str.replace(' ', '-')))
name_dict.update(zip(df_jgi_metadata['acc'], df_jgi_metadata['loc'].str[:2] + df_jgi_metadata['acc'].str.split('_', expand=True)[1].str.lstrip('0')))
name_dict.update(zip(df_yutin_metadata['acc'], df_yutin_metadata['acc'].str.split('.', expand=True)[0]))

renamed = []
for record in SeqIO.parse('../data/tree/P9/P9.afa', 'fasta'):
    name = record.id.split('_orf')[0]
    if name in name_dict.keys():
        new_name = name_dict[name]
    else:
        new_name = name
        
    record.id = new_name
    
    renamed.append(record)
    
    
#SeqIO.write(renamed, '../data/tree/P9/P9.phy', 'phylip')

# %%
aln_phy = '../data/tree/P9/P9.phy'
phy_cmd = 'phyml '\
            '-d aa '\
            '-m LG ' \
            '-b -4 '\
            '-v 0.0 '\
            '-c 4 '\
            '-a e '\
            '-f e '\
            '--no_memory_check '\
            f'-i {aln_phy}'

# %%
#!phy_cmd

# %%
print(phy_cmd)
# Out:
# phyml -d aa -m LG -b -4 -v 0.0 -c 4 -a e -f e --no_memory_check -i ../data/tree/P9/P9.phy
